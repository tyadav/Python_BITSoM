# %% [markdown]
# # Lecture 02 — Coding Problems

# %% [markdown]
# These five short problems reinforce Lecture 02 concepts (booleans, conditionals, loops, range, string checks) and build on Lecture 01 skills (strings and lists). Each problem includes quick self-checks.

# %% [markdown]
# These easier, popular exercises validate Lecture 02 control flow/loops and Lecture 01 strings/lists.

# %% [markdown]
# ### Problem A — Even or Odd (list)
# Return a list of 'even'/'odd' labels for each integer in the input list.

# %%
# TODO: implement even_or_odd(nums)

def even_or_odd(nums):
    """Return list[str] with 'even' or 'odd' per number."""
    raise NotImplementedError

# %%
# Self-check
assert even_or_odd([1,2,3,4]) == ['odd','even','odd','even']
assert even_or_odd([]) == []
print('A OK')

# %% [markdown]
# ### Problem B — Sum 1..n (loop)
# Compute the sum of integers from 1 to n inclusive using a loop (no sum()).

# %%
# TODO: implement sum_to_n(n)

def sum_to_n(n: int) -> int:
    """Return 1+2+...+n; assume n>=0."""
    raise NotImplementedError

# %%
# Self-check
assert sum_to_n(0) == 0
assert sum_to_n(5) == 15
assert sum_to_n(10) == 55
print('B OK')

# %% [markdown]
# ### Problem C — Count Vowels
# Return the number of vowels (a,e,i,o,u) in a string (case-insensitive).

# %%
# TODO: implement count_vowels(s)

def count_vowels(s: str) -> int:
    """Count a,e,i,o,u (case-insensitive)."""
    raise NotImplementedError

# %%
# Self-check
assert count_vowels('Python') == 1
assert count_vowels('Education') == 5
assert count_vowels('') == 0
print('C OK')

# %% [markdown]
# ### Problem D — Multiplication Table Lines
# Return a list of lines like 'n x i = product' for i=1..upto (default 10).

# %%
# TODO: implement mult_table(n, upto=10)

def mult_table(n: int, upto: int = 10) -> list[str]:
    """Return lines for n x 1..upto."""
    raise NotImplementedError

# %%
# Self-check
assert mult_table(3, 3) == ['3 x 1 = 3', '3 x 2 = 6', '3 x 3 = 9']
print('D OK')

# %% [markdown]
# ### Problem E — Find Minimum (loop)
# Return the smallest number in a list using a loop (no min()). Return None for empty list.

# %%
# TODO: implement find_min(nums)

def find_min(nums):
    """Return minimum or None for empty list."""
    raise NotImplementedError

# %%
# Self-check
assert find_min([5,2,9,1,7]) == 1
assert find_min([-3, -1, -10]) == -10
assert find_min([]) is None
print('E OK')

# %% [markdown]
# ## Problem 1 — FizzBuzz Range
# Return a list of strings for 1..n where multiples of 3 are 'Fizz', multiples of 5 are 'Buzz', and multiples of both are 'FizzBuzz'. Others are their number.
#
# Concepts: `range`, `for`, `if/elif/else`, `%` modulus, list building.

# %%
# TODO: implement fizzbuzz(n)
def fizzbuzz(n):
    """Return list[str] for 1..n using FizzBuzz rules.
    Examples: 3 -> ['1','2','Fizz']
    """
    raise NotImplementedError

# %%
# Self-check
assert fizzbuzz(5) == ['1','2','Fizz','4','Buzz']
fb15 = fizzbuzz(15)
assert fb15[-5:] == ['11','Fizz','13','14','FizzBuzz']
print('Problem 1 OK')

# %% [markdown]
# ## Problem 4 — Palindrome Check (normalized)
# Return True if the input is a palindrome ignoring case and spaces/punctuation.
#
# Concepts: normalization (`lower`, filtering with `isalpha`/`isspace`/membership), slicing, conditionals.

# %%
# TODO: implement is_palindrome(text)
def is_palindrome(text):
    """Case/space/punctuation-insensitive palindrome check.
    """
    raise NotImplementedError

# %%
# Self-check
assert is_palindrome('Never odd or even')
assert is_palindrome('No lemon, no melon')
assert not is_palindrome('Python')
print('Problem 4 OK')
